# %%
# !git clone https://github.com/ultralytics/ultralytics.git
# Out:
# Cloning into 'ultralytics'...
# remote: Enumerating objects: 50778, done.
# remote: Counting objects: 100% (389/389), done.
# remote: Compressing objects: 100% (176/176), done.
# remote: Total 50778 (delta 344), reused 213 (delta 213), pack-reused 50389 (from 2)
# Receiving objects: 100% (50778/50778), 28.95 MiB | 26.46 MiB/s, done.
# Resolving deltas: 100% (37560/37560), done.

# %%
pip install ultralytics --upgrade
# Out:
# Collecting ultralytics
#   Downloading ultralytics-8.3.74-py3-none-any.whl.metadata (35 kB)
# Requirement already satisfied: numpy<=2.1.1,>=1.23.0 in /usr/local/lib/python3.10/dist-packages (from ultralytics) (1.26.4)
# Requirement already satisfied: matplotlib>=3.3.0 in /usr/local/lib/python3.10/dist-packages (from ultralytics) (3.7.5)
# Requirement already satisfied: opencv-python>=4.6.0 in /usr/local/lib/python3.10/dist-packages (from ultralytics) (4.10.0.84)
# Requirement already satisfied: pillow>=7.1.2 in /usr/local/lib/python3.10/dist-packages (from ultralytics) (11.0.0)
# Requirement already satisfied: pyyaml>=5.3.1 in /usr/local/lib/python3.10/dist-packages (from ultralytics) (6.0.2)
# Requirement already satisfied: requests>=2.23.0 in /usr/local/lib/python3.10/dist-packages (from ultralytics) (2.32.3)
# Requirement already satisfied: scipy>=1.4.1 in /usr/local/lib/python3.10/dist-packages (from ultralytics) (1.13.1)
# Requirement already satisfied: torch>=1.8.0 in /usr/local/lib/python3.10/dist-packages (from ultralytics) (2.5.1+cu121)
# Requirement already satisfied: torchvision>=0.9.0 in /usr/local/lib/python3.10/dist-packages (from ultralytics) (0.20.1+cu121)
# Requirement already satisfied: tqdm>=4.64.0 in /usr/local/lib/python3.10/dist-packages (from ultralytics) (4.67.1)
# Requirement already satisfied: psutil in /usr/local/lib/python3.10/dist-packages (from ultralytics) (5.9.5)
# Requirement already satisfied: py-cpuinfo in /usr/local/lib/python3.10/dist-packages (from ultralytics) (9.0.0)
# Requirement already satisfied: pandas>=1.1.4 in /usr/local/lib/python3.10/dist-packages (from ultralytics) (2.2.3)
# Requirement already satisfied: seaborn>=0.11.0 in /usr/local/lib/python3.10/dist-packages (from ultralytics) (0.12.2)
# Collecting ultralytics-thop>=2.0.0 (from ultralytics)
#   Downloading ultralytics_thop-2.0.14-py3-none-any.whl.metadata (9.4 kB)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.3.0->ultralytics) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.3.0->ultralytics) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.3.0->ultralytics) (4.55.3)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.3.0->ultralytics) (1.4.7)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.3.0->ultralytics) (24.2)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.3.0->ultralytics) (3.2.0)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.3.0->ultralytics) (2.9.0.post0)
# Requirement already satisfied: mkl_fft in /usr/local/lib/python3.10/dist-packages (from numpy<=2.1.1,>=1.23.0->ultralytics) (1.3.8)
# Requirement already satisfied: mkl_random in /usr/local/lib/python3.10/dist-packages (from numpy<=2.1.1,>=1.23.0->ultralytics) (1.2.4)
# Requirement already satisfied: mkl_umath in /usr/local/lib/python3.10/dist-packages (from numpy<=2.1.1,>=1.23.0->ultralytics) (0.1.1)
# Requirement already satisfied: mkl in /usr/local/lib/python3.10/dist-packages (from numpy<=2.1.1,>=1.23.0->ultralytics) (2025.0.1)
# Requirement already satisfied: tbb4py in /usr/local/lib/python3.10/dist-packages (from numpy<=2.1.1,>=1.23.0->ultralytics) (2022.0.0)
# Requirement already satisfied: mkl-service in /usr/local/lib/python3.10/dist-packages (from numpy<=2.1.1,>=1.23.0->ultralytics) (2.4.1)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.1.4->ultralytics) (2025.1)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.1.4->ultralytics) (2025.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests>=2.23.0->ultralytics) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests>=2.23.0->ultralytics) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests>=2.23.0->ultralytics) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests>=2.23.0->ultralytics) (2025.1.31)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch>=1.8.0->ultralytics) (3.17.0)
# Requirement already satisfied: typing-extensions>=4.8.0 in /usr/local/lib/python3.10/dist-packages (from torch>=1.8.0->ultralytics) (4.12.2)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch>=1.8.0->ultralytics) (3.4.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch>=1.8.0->ultralytics) (3.1.4)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from torch>=1.8.0->ultralytics) (2024.9.0)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.10/dist-packages (from torch>=1.8.0->ultralytics) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from sympy==1.13.1->torch>=1.8.0->ultralytics) (1.3.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.7->matplotlib>=3.3.0->ultralytics) (1.17.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch>=1.8.0->ultralytics) (3.0.2)
# Requirement already satisfied: intel-openmp>=2024 in /usr/local/lib/python3.10/dist-packages (from mkl->numpy<=2.1.1,>=1.23.0->ultralytics) (2024.2.0)
# Requirement already satisfied: tbb==2022.* in /usr/local/lib/python3.10/dist-packages (from mkl->numpy<=2.1.1,>=1.23.0->ultralytics) (2022.0.0)
# Requirement already satisfied: tcmlib==1.* in /usr/local/lib/python3.10/dist-packages (from tbb==2022.*->mkl->numpy<=2.1.1,>=1.23.0->ultralytics) (1.2.0)
# Requirement already satisfied: intel-cmplr-lib-rt in /usr/local/lib/python3.10/dist-packages (from mkl_umath->numpy<=2.1.1,>=1.23.0->ultralytics) (2024.2.0)
# Requirement already satisfied: intel-cmplr-lib-ur==2024.2.0 in /usr/local/lib/python3.10/dist-packages (from intel-openmp>=2024->mkl->numpy<=2.1.1,>=1.23.0->ultralytics) (2024.2.0)
# Downloading ultralytics-8.3.74-py3-none-any.whl (914 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 914.7/914.7 kB 16.2 MB/s eta 0:00:00
# Downloading ultralytics_thop-2.0.14-py3-none-any.whl (26 kB)
# Installing collected packages: ultralytics-thop, ultralytics
# Successfully installed ultralytics-8.3.74 ultralytics-thop-2.0.14
# Note: you may need to restart the kernel to use updated packages.

# %%
cd ultralytics
# Out:
# /kaggle/working/ultralytics

# %%
# !pip install -e .
# Out:
# Obtaining file:///kaggle/working/ultralytics
#   Installing build dependencies ... done
#   Checking if build backend supports build_editable ... done
#   Getting requirements to build editable ... done
#   Preparing editable metadata (pyproject.toml) ... done
# Requirement already satisfied: numpy<=2.1.1,>=1.23.0 in /usr/local/lib/python3.10/dist-packages (from ultralytics==8.3.74) (1.26.4)
# Requirement already satisfied: matplotlib>=3.3.0 in /usr/local/lib/python3.10/dist-packages (from ultralytics==8.3.74) (3.7.5)
# Requirement already satisfied: opencv-python>=4.6.0 in /usr/local/lib/python3.10/dist-packages (from ultralytics==8.3.74) (4.10.0.84)
# Requirement already satisfied: pillow>=7.1.2 in /usr/local/lib/python3.10/dist-packages (from ultralytics==8.3.74) (11.0.0)
# Requirement already satisfied: pyyaml>=5.3.1 in /usr/local/lib/python3.10/dist-packages (from ultralytics==8.3.74) (6.0.2)
# Requirement already satisfied: requests>=2.23.0 in /usr/local/lib/python3.10/dist-packages (from ultralytics==8.3.74) (2.32.3)
# Requirement already satisfied: scipy>=1.4.1 in /usr/local/lib/python3.10/dist-packages (from ultralytics==8.3.74) (1.13.1)
# Requirement already satisfied: torch>=1.8.0 in /usr/local/lib/python3.10/dist-packages (from ultralytics==8.3.74) (2.5.1+cu121)
# Requirement already satisfied: torchvision>=0.9.0 in /usr/local/lib/python3.10/dist-packages (from ultralytics==8.3.74) (0.20.1+cu121)
# Requirement already satisfied: tqdm>=4.64.0 in /usr/local/lib/python3.10/dist-packages (from ultralytics==8.3.74) (4.67.1)
# Requirement already satisfied: psutil in /usr/local/lib/python3.10/dist-packages (from ultralytics==8.3.74) (5.9.5)
# Requirement already satisfied: py-cpuinfo in /usr/local/lib/python3.10/dist-packages (from ultralytics==8.3.74) (9.0.0)
# Requirement already satisfied: pandas>=1.1.4 in /usr/local/lib/python3.10/dist-packages (from ultralytics==8.3.74) (2.2.3)
# Requirement already satisfied: seaborn>=0.11.0 in /usr/local/lib/python3.10/dist-packages (from ultralytics==8.3.74) (0.12.2)
# Requirement already satisfied: ultralytics-thop>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from ultralytics==8.3.74) (2.0.14)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.3.0->ultralytics==8.3.74) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.3.0->ultralytics==8.3.74) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.3.0->ultralytics==8.3.74) (4.55.3)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.3.0->ultralytics==8.3.74) (1.4.7)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.3.0->ultralytics==8.3.74) (24.2)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.3.0->ultralytics==8.3.74) (3.2.0)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.3.0->ultralytics==8.3.74) (2.9.0.post0)
# Requirement already satisfied: mkl_fft in /usr/local/lib/python3.10/dist-packages (from numpy<=2.1.1,>=1.23.0->ultralytics==8.3.74) (1.3.8)
# Requirement already satisfied: mkl_random in /usr/local/lib/python3.10/dist-packages (from numpy<=2.1.1,>=1.23.0->ultralytics==8.3.74) (1.2.4)
# Requirement already satisfied: mkl_umath in /usr/local/lib/python3.10/dist-packages (from numpy<=2.1.1,>=1.23.0->ultralytics==8.3.74) (0.1.1)
# Requirement already satisfied: mkl in /usr/local/lib/python3.10/dist-packages (from numpy<=2.1.1,>=1.23.0->ultralytics==8.3.74) (2025.0.1)
# Requirement already satisfied: tbb4py in /usr/local/lib/python3.10/dist-packages (from numpy<=2.1.1,>=1.23.0->ultralytics==8.3.74) (2022.0.0)
# Requirement already satisfied: mkl-service in /usr/local/lib/python3.10/dist-packages (from numpy<=2.1.1,>=1.23.0->ultralytics==8.3.74) (2.4.1)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.1.4->ultralytics==8.3.74) (2025.1)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.1.4->ultralytics==8.3.74) (2025.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests>=2.23.0->ultralytics==8.3.74) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests>=2.23.0->ultralytics==8.3.74) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests>=2.23.0->ultralytics==8.3.74) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests>=2.23.0->ultralytics==8.3.74) (2025.1.31)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch>=1.8.0->ultralytics==8.3.74) (3.17.0)
# Requirement already satisfied: typing-extensions>=4.8.0 in /usr/local/lib/python3.10/dist-packages (from torch>=1.8.0->ultralytics==8.3.74) (4.12.2)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch>=1.8.0->ultralytics==8.3.74) (3.4.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch>=1.8.0->ultralytics==8.3.74) (3.1.4)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from torch>=1.8.0->ultralytics==8.3.74) (2024.9.0)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.10/dist-packages (from torch>=1.8.0->ultralytics==8.3.74) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from sympy==1.13.1->torch>=1.8.0->ultralytics==8.3.74) (1.3.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.7->matplotlib>=3.3.0->ultralytics==8.3.74) (1.17.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch>=1.8.0->ultralytics==8.3.74) (3.0.2)
# Requirement already satisfied: intel-openmp>=2024 in /usr/local/lib/python3.10/dist-packages (from mkl->numpy<=2.1.1,>=1.23.0->ultralytics==8.3.74) (2024.2.0)
# Requirement already satisfied: tbb==2022.* in /usr/local/lib/python3.10/dist-packages (from mkl->numpy<=2.1.1,>=1.23.0->ultralytics==8.3.74) (2022.0.0)
# Requirement already satisfied: tcmlib==1.* in /usr/local/lib/python3.10/dist-packages (from tbb==2022.*->mkl->numpy<=2.1.1,>=1.23.0->ultralytics==8.3.74) (1.2.0)
# Requirement already satisfied: intel-cmplr-lib-rt in /usr/local/lib/python3.10/dist-packages (from mkl_umath->numpy<=2.1.1,>=1.23.0->ultralytics==8.3.74) (2024.2.0)
# Requirement already satisfied: intel-cmplr-lib-ur==2024.2.0 in /usr/local/lib/python3.10/dist-packages (from intel-openmp>=2024->mkl->numpy<=2.1.1,>=1.23.0->ultralytics==8.3.74) (2024.2.0)
# Building wheels for collected packages: ultralytics
#   Building editable for ultralytics (pyproject.toml) ... done
#   Created wheel for ultralytics: filename=ultralytics-8.3.74-0.editable-py3-none-any.whl size=22690 sha256=f8eb365d44858a08d0ed7c1a8144c5eb29ed986c56561aea60c5a7aca0b8d6b9
#   Stored in directory: /tmp/pip-ephem-wheel-cache-fpjgowf1/wheels/1b/eb/7d/853f2df0532389050170c8cd117b40e1fef8d125854a910fe6
# Successfully built ultralytics
# Installing collected packages: ultralytics
#   Attempting uninstall: ultralytics
#     Found existing installation: ultralytics 8.3.74
#     Uninstalling ultralytics-8.3.74:
#       Successfully uninstalled ultralytics-8.3.74
# Successfully installed ultralytics-8.3.74

# %%
# !ls /kaggle/working/ultralytics
# Out:
# CITATION.cff	 examples	 README.md	  ultralytics.egg-info
# CONTRIBUTING.md  LICENSE	 README.zh-CN.md
# docker		 mkdocs.yml	 tests
# docs		 pyproject.toml  ultralytics

# %%
# !cp -r /kaggle/input/dataset_Yolo_version_13pestTypes /kaggle/working/dataset

# %%
# !echo -e "" > /kaggle/working/dataset.yaml

# %%
yaml_content = """
path: /kaggle/working/dataset
train: train/images
val: val/images
test: test/images

nc: 13
names: ["IP014", "IP015", "IP016", "IP022", "IP024", "IP040", "IP046", "IP049", "IP051", "IP052", "IP071", "IP087", "IP102"]
"""

with open("/kaggle/working/dataset.yaml", "w") as f:
    f.write(yaml_content)

# %%
# !wandb login 4f59467c9d10d7a53805775f226ee2d29eba5e5b
# Out:
# wandb: WARNING If you're specifying your api key in code, ensure this code is not shared publicly.
# wandb: WARNING Consider setting the WANDB_API_KEY environment variable, or running `wandb login` from the command line.
# wandb: Appending key for api.wandb.ai to your netrc file: /root/.netrc

# %%
# !yolo settings wandb=True
# Out:
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.
# JSONDict("/root/.config/Ultralytics/settings.json"):
# {
#   "settings_version": "0.0.6",
#   "datasets_dir": "/kaggle/working/datasets",
#   "weights_dir": "/kaggle/working/ultralytics/weights",
#   "runs_dir": "/kaggle/working/ultralytics/runs",
#   "uuid": "1bfc3e992d24318da58ddee183be5bf9388a31f26bab1738e986ec4d297417ff",
#   "sync": true,
#   "api_key": "",
#   "openai_api_key": "",
#   "clearml": true,
#   "comet": true,
#   "dvc": true,
#   "hub": true,
#   "mlflow": true,
#   "neptune": true,
#   "raytune": true,
#   "tensorboard": true,
#   "wandb": true,
#   "vscode_msg": true
# }
# 💡 Learn more about Ultralytics Settings at https://docs.ultralytics.com/quickstart/#ultralytics-settings

# %%
# !sed -i 's/ray.train._internal.session._get_session()/ray.train._internal.session.get_session()/g' /kaggle/working/ultralytics/ultralytics/utils/callbacks/raytune.py

# %%
# !yolo task=detect mode=train model=yolov10s.pt \
  data=/kaggle/working/dataset.yaml \
  epochs=60 imgsz=640 batch=16 \
  optimizer=SGD  \
  project="wandb" name="yolov10_training"
# Out:
# Downloading https://github.com/ultralytics/assets/releases/download/v8.3.0/yolov10s.pt to 'yolov10s.pt'...
# 100%|███████████████████████████████████████| 15.9M/15.9M [00:00<00:00, 123MB/s]
# Ultralytics 8.3.74 🚀 Python-3.10.12 torch-2.5.1+cu121 CUDA:0 (Tesla T4, 15095MiB)
# engine/trainer: task=detect, mode=train, model=yolov10s.pt, data=/kaggle/working/dataset.yaml, epochs=60, time=None, patience=100, batch=16, imgsz=640, save=True, save_period=-1, cache=False, device=None, workers=8, project=wandb, name=yolov10_training, exist_ok=False, pretrained=True, optimizer=SGD, verbose=True, seed=0, deterministic=True, single_cls=False, rect=False, cos_lr=False, close_mosaic=10, resume=False, amp=True, fraction=1.0, profile=False, freeze=None, multi_scale=False, overlap_mask=True, mask_ratio=4, dropout=0.0, val=True, split=val, save_json=False, save_hybrid=False, conf=None, iou=0.7, max_det=300, half=False, dnn=False, plots=True, source=None, vid_stride=1, stream_buffer=False, visualize=False, augment=False, agnostic_nms=False, classes=None, retina_masks=False, embed=None, show=False, save_frames=False, save_txt=False, save_conf=False, save_crop=False, show_labels=True, show_conf=True, show_boxes=True, line_width=None, format=torchscript, keras=False, optimize=False, int8=False, dynamic=False, simplify=True, opset=None, workspace=None, nms=False, lr0=0.01, lrf=0.01, momentum=0.937, weight_decay=0.0005, warmup_epochs=3.0, warmup_momentum=0.8, warmup_bias_lr=0.1, box=7.5, cls=0.5, dfl=1.5, pose=12.0, kobj=1.0, nbs=64, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, degrees=0.0, translate=0.1, scale=0.5, shear=0.0, perspective=0.0, flipud=0.0, fliplr=0.5, bgr=0.0, mosaic=1.0, mixup=0.0, copy_paste=0.0, copy_paste_mode=flip, auto_augment=randaugment, erasing=0.4, crop_fraction=1.0, cfg=None, tracker=botsort.yaml, save_dir=wandb/yolov10_training
# Downloading https://ultralytics.com/assets/Arial.ttf to '/root/.config/Ultralytics/Arial.ttf'...
# 100%|████████████████████████████████████████| 755k/755k [00:00<00:00, 17.6MB/s]
# Overriding model.yaml nc=80 with nc=13
#
#                    from  n    params  module                                       arguments
#   0                  -1  1       928  ultralytics.nn.modules.conv.Conv             [3, 32, 3, 2]
#   1                  -1  1     18560  ultralytics.nn.modules.conv.Conv             [32, 64, 3, 2]
#   2                  -1  1     29056  ultralytics.nn.modules.block.C2f             [64, 64, 1, True]
#   3                  -1  1     73984  ultralytics.nn.modules.conv.Conv             [64, 128, 3, 2]
#   4                  -1  2    197632  ultralytics.nn.modules.block.C2f             [128, 128, 2, True]
#   5                  -1  1     36096  ultralytics.nn.modules.block.SCDown          [128, 256, 3, 2]
#   6                  -1  2    788480  ultralytics.nn.modules.block.C2f             [256, 256, 2, True]
#   7                  -1  1    137728  ultralytics.nn.modules.block.SCDown          [256, 512, 3, 2]
#   8                  -1  1    958464  ultralytics.nn.modules.block.C2fCIB          [512, 512, 1, True, True]
#   9                  -1  1    656896  ultralytics.nn.modules.block.SPPF            [512, 512, 5]
#  10                  -1  1    990976  ultralytics.nn.modules.block.PSA             [512, 512]
#  11                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  12             [-1, 6]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  13                  -1  1    591360  ultralytics.nn.modules.block.C2f             [768, 256, 1]
#  14                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  15             [-1, 4]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  16                  -1  1    148224  ultralytics.nn.modules.block.C2f             [384, 128, 1]
#  17                  -1  1    147712  ultralytics.nn.modules.conv.Conv             [128, 128, 3, 2]
#  18            [-1, 13]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  19                  -1  1    493056  ultralytics.nn.modules.block.C2f             [384, 256, 1]
#  20                  -1  1     68864  ultralytics.nn.modules.block.SCDown          [256, 256, 3, 2]
#  21            [-1, 10]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  22                  -1  1   1089536  ultralytics.nn.modules.block.C2fCIB          [768, 512, 1, True, True]
#  23        [16, 19, 22]  1   1648862  ultralytics.nn.modules.head.v10Detect        [13, [128, 256, 512]]
# YOLOv10s summary: 402 layers, 8,076,414 parameters, 8,076,398 gradients, 24.8 GFLOPs
#
# Transferred 607/619 items from pretrained weights
# TensorBoard: Start with 'tensorboard --logdir wandb/yolov10_training', view at http://localhost:6006/
# wandb: Using wandb-core as the SDK backend.  Please refer to https://wandb.me/wandb-core for more information.
# wandb: Currently logged in as: younes1967-yy (mehdi-esi-alger). Use `wandb login --relogin` to force relogin
# wandb: Tracking run with wandb version 0.19.1
# wandb: Run data is saved locally in /kaggle/working/ultralytics/wandb/run-20250212_171805-3ju2iy5n
# wandb: Run `wandb offline` to turn off syncing.
# wandb: Syncing run yolov10_training
# wandb: ⭐️ View project at https://wandb.ai/mehdi-esi-alger/wandb
# wandb: 🚀 View run at https://wandb.ai/mehdi-esi-alger/wandb/runs/3ju2iy5n
# Freezing layer 'model.23.dfl.conv.weight'
# AMP: running Automatic Mixed Precision (AMP) checks...
# Downloading https://github.com/ultralytics/assets/releases/download/v8.3.0/yolo11n.pt to 'yolo11n.pt'...
# 100%|██████████████████████████████████████| 5.35M/5.35M [00:00<00:00, 75.1MB/s]
# AMP: checks passed ✅
# train: Scanning /kaggle/working/dataset/train/labels... 8745 images, 0 backgroun
# train: New cache created: /kaggle/working/dataset/train/labels.cache
# /usr/local/lib/python3.10/dist-packages/albumentations/__init__.py:24: UserWarning: A new version of Albumentations is available: 2.0.4 (you have 1.4.20). Upgrade using: pip install -U albumentations. To disable automatic update checks, set the environment variable NO_ALBUMENTATIONS_UPDATE to 1.
#   check_for_updates()
# albumentations: Blur(p=0.01, blur_limit=(3, 7)), MedianBlur(p=0.01, blur_limit=(3, 7)), ToGray(p=0.01, num_output_channels=3, method='weighted_average'), CLAHE(p=0.01, clip_limit=(1.0, 4.0), tile_grid_size=(8, 8))
# val: Scanning /kaggle/working/dataset/val/labels... 1089 images, 0 backgrounds,
# val: New cache created: /kaggle/working/dataset/val/labels.cache
# Plotting labels to wandb/yolov10_training/labels.jpg...
# optimizer: SGD(lr=0.01, momentum=0.937) with parameter groups 99 weight(decay=0.0), 112 weight(decay=0.0005), 111 bias(decay=0.0)
# TensorBoard: model graph visualization added ✅
# Image sizes 640 train, 640 val
# Using 2 dataloader workers
# Logging results to wandb/yolov10_training
# Starting training for 60 epochs...
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        1/60      5.22G      2.585      6.399      3.156         25        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all       1089       1618      0.515      0.605      0.566      0.348
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        2/60      5.18G      2.535      3.272      2.994         22        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all       1089       1618      0.556       0.56      0.554      0.329
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        3/60      5.18G      2.758      3.622      3.152         37        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all       1089       1618      0.509      0.389      0.402      0.214
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        4/60      5.19G      2.874      3.862      3.215         31        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all       1089       1618      0.521      0.555      0.566      0.306
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        5/60      5.17G      2.771      3.553      3.143         27        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all       1089       1618      0.589      0.533       0.59      0.351
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        6/60      5.19G      2.688       3.38      3.079         36        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all       1089       1618      0.624      0.606      0.647      0.398
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        7/60      5.34G       2.64       3.16      3.037         21        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all       1089       1618      0.643       0.65       0.68      0.424
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        8/60      5.19G      2.569      2.971      2.983         27        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all       1089       1618      0.687      0.671      0.725       0.46
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        9/60      5.17G      2.527      2.879      2.954         26        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all       1089       1618        0.7      0.718       0.75      0.483
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       10/60      5.18G       2.48      2.783      2.935         25        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all       1089       1618      0.693      0.743      0.774      0.497
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       11/60      5.19G      2.464      2.679       2.93         24        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all       1089       1618      0.738       0.74      0.793      0.516
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       12/60      5.18G      2.416       2.61      2.883         36        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all       1089       1618      0.761      0.766      0.818      0.544
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       13/60      5.18G      2.391       2.55       2.87         24        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all       1089       1618      0.779      0.751      0.825      0.542
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       14/60      5.19G      2.384      2.487      2.875         31        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all       1089       1618      0.757      0.786      0.826      0.556
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       15/60      5.35G      2.345      2.421      2.834         31        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all       1089       1618      0.775      0.756      0.831       0.56
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       16/60      5.21G      2.312      2.359      2.819         25        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all       1089       1618      0.787      0.785       0.85      0.581
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       17/60      5.17G      2.311      2.304      2.817         32        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all       1089       1618      0.792      0.764      0.833      0.568
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       18/60      5.19G      2.287      2.227      2.794         34        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all       1089       1618       0.78      0.805      0.853      0.588
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       19/60      5.18G      2.263      2.199      2.784         33        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all       1089       1618      0.793      0.819      0.868        0.6
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       20/60      5.18G      2.233      2.161      2.758         27        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all       1089       1618      0.784      0.826       0.87      0.599
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       21/60      5.18G      2.232      2.086      2.751         28        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all       1089       1618      0.827       0.82      0.876      0.614
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       22/60      5.18G      2.213      2.067      2.742         21        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all       1089       1618      0.843      0.809       0.88       0.61
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       23/60      5.18G      2.185      2.046      2.724         26        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all       1089       1618      0.834      0.832      0.901      0.631
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       24/60      5.19G      2.182      2.007      2.724         38        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all       1089       1618      0.825      0.842       0.89      0.628
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       25/60      5.18G      2.157       1.97      2.705         21        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all       1089       1618      0.865      0.827      0.904      0.636
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       26/60       5.2G       2.15       1.93      2.704         29        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all       1089       1618      0.864      0.845      0.906      0.635
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       27/60      5.19G      2.132       1.92       2.69         35        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all       1089       1618       0.85      0.841        0.9      0.637
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       28/60      5.18G      2.129      1.899      2.696         40        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all       1089       1618       0.85      0.857      0.911      0.651
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       29/60      5.17G      2.102      1.824      2.671         38        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all       1089       1618      0.876      0.839      0.903      0.651
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       30/60      5.19G      2.081      1.805      2.665         37        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all       1089       1618       0.85      0.849      0.916      0.658
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       31/60      5.22G      2.084       1.78      2.656         28        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all       1089       1618       0.88      0.862      0.917       0.66
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       32/60      5.19G       2.06      1.739      2.644         30        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all       1089       1618      0.859       0.87      0.918      0.664
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       33/60      5.18G      2.035      1.697      2.626         31        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all       1089       1618       0.87      0.846      0.911      0.669
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       34/60      5.18G      2.021      1.674      2.617         27        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all       1089       1618      0.885      0.859      0.924      0.673
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       35/60      5.19G      2.019      1.673      2.621         30        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all       1089       1618      0.881      0.868      0.925      0.678
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       36/60      5.19G      2.004      1.637      2.613         23        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all       1089       1618      0.878      0.864       0.92      0.678
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       37/60      5.18G      1.982        1.6      2.592         27        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all       1089       1618      0.886      0.865       0.92      0.676
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       38/60      5.18G      1.973      1.604      2.597         30        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all       1089       1618       0.88       0.87      0.929      0.685
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       39/60      5.19G      1.945      1.596      2.567         36        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all       1089       1618      0.891      0.869      0.926      0.685
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       40/60      5.19G      1.929      1.528      2.556         30        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all       1089       1618      0.873      0.877      0.925      0.684
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       41/60      5.17G      1.935      1.516      2.554         28        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all       1089       1618      0.894      0.867      0.928      0.687
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       42/60      5.19G      1.908      1.495      2.548         28        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all       1089       1618      0.889      0.884      0.932      0.694
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       43/60      5.18G      1.898      1.461      2.534         19        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all       1089       1618      0.898      0.882      0.931      0.692
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       44/60      5.18G      1.872      1.447       2.52         23        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all       1089       1618      0.914      0.871      0.936      0.697
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       45/60      5.17G      1.865      1.398      2.511         25        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all       1089       1618      0.905      0.877      0.934      0.696
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       46/60      5.18G      1.831      1.361      2.485         32        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all       1089       1618      0.894      0.893      0.937        0.7
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       47/60      5.19G      1.817      1.356      2.486         31        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all       1089       1618      0.894      0.893      0.934      0.704
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       48/60      5.18G      1.804      1.349       2.48         27        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all       1089       1618      0.907      0.877      0.936      0.705
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       49/60      5.18G      1.781      1.316      2.465         31        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all       1089       1618      0.903       0.87      0.936      0.706
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       50/60      5.18G      1.767       1.29       2.46         24        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all       1089       1618        0.9      0.885      0.934      0.706
# Closing dataloader mosaic
# albumentations: Blur(p=0.01, blur_limit=(3, 7)), MedianBlur(p=0.01, blur_limit=(3, 7)), ToGray(p=0.01, num_output_channels=3, method='weighted_average'), CLAHE(p=0.01, clip_limit=(1.0, 4.0), tile_grid_size=(8, 8))
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       51/60      5.34G      1.557     0.7469      2.492         14        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all       1089       1618      0.899      0.871       0.93      0.702
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       52/60      5.17G      1.515     0.7053      2.439         20        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all       1089       1618      0.909      0.881      0.937      0.711
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       53/60      5.16G      1.478     0.6815      2.414         12        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all       1089       1618      0.914      0.873      0.935      0.711
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       54/60       5.2G      1.445     0.6574      2.392         12        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all       1089       1618      0.912      0.878      0.932      0.709
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       55/60      5.18G      1.417     0.6419      2.374         13        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all       1089       1618      0.915      0.876      0.935      0.713
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       56/60      5.18G        1.4     0.6188      2.358         13        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all       1089       1618      0.895       0.89      0.934      0.713
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       57/60      5.17G      1.366     0.6016      2.338         12        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all       1089       1618      0.908      0.879      0.933      0.714
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       58/60      5.18G      1.345     0.5927      2.326         13        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all       1089       1618      0.898      0.886      0.934      0.716
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       59/60      5.33G      1.321      0.581      2.307         11        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all       1089       1618      0.905      0.882      0.934      0.716
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       60/60      5.18G      1.295     0.5627      2.293         13        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all       1089       1618      0.896      0.887      0.933      0.714
#
# 60 epochs completed in 3.683 hours.
# Optimizer stripped from wandb/yolov10_training/weights/last.pt, 16.5MB
# Optimizer stripped from wandb/yolov10_training/weights/best.pt, 16.5MB
#
# Validating wandb/yolov10_training/weights/best.pt...
# Ultralytics 8.3.74 🚀 Python-3.10.12 torch-2.5.1+cu121 CUDA:0 (Tesla T4, 15095MiB)
# YOLOv10s summary (fused): 293 layers, 8,045,022 parameters, 0 gradients, 24.5 GFLOPs
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all       1089       1618      0.901      0.883      0.934      0.716
#                  IP014         83        197      0.964      0.955      0.978      0.809
#                  IP015         86         87          1      0.942      0.992      0.614
#                  IP016         82        146      0.963      0.979      0.979      0.887
#                  IP022         82        124      0.945      0.975      0.985      0.847
#                  IP024         87        155      0.776      0.768      0.828       0.48
#                  IP040         81        122      0.934      0.918      0.962      0.839
#                  IP046         80        130      0.909      0.908      0.954      0.845
#                  IP049         83        123      0.833      0.854      0.924      0.726
#                  IP051         83        134      0.881      0.866       0.93      0.753
#                  IP052         87         92       0.79      0.779      0.834      0.428
#                  IP071         87         87      0.832      0.678      0.838      0.514
#                  IP087         81        132      0.905      0.902      0.961      0.827
#                  IP102         87         89      0.981      0.955      0.981      0.734
# /usr/local/lib/python3.10/dist-packages/matplotlib/colors.py:721: RuntimeWarning: invalid value encountered in less
#   xa[xa < 0] = -1
# /usr/local/lib/python3.10/dist-packages/matplotlib/colors.py:721: RuntimeWarning: invalid value encountered in less
#   xa[xa < 0] = -1
# Speed: 0.1ms preprocess, 5.1ms inference, 0.0ms loss, 0.2ms postprocess per image
# Results saved to wandb/yolov10_training
# wandb:
# wandb:
# wandb: Run history:
# wandb:                  lr/pg0 █▅▂▂▂▂▂▂▂▂▂▂▂▂▂▂▂▂▂▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁
# wandb:                  lr/pg1 ▃▆███▇▇▇▇▇▇▆▆▆▆▆▆▅▅▅▅▅▄▄▄▄▄▃▃▃▃▂▂▂▂▂▁▁▁▁
# wandb:                  lr/pg2 ▃▆███▇▇▇▇▇▇▇▆▆▆▆▆▅▅▅▅▄▄▄▄▃▃▃▃▃▃▃▃▂▂▂▂▁▁▁
# wandb:        metrics/mAP50(B) ▃▃▁▃▃▅▅▆▆▆▇▇▇▇▇█▇███████████████████████
# wandb:     metrics/mAP50-95(B) ▃▃▁▂▄▄▅▅▆▆▆▆▆▇▇▇▇▇▇▇▇▇▇▇▇███████████████
# wandb:    metrics/precision(B) ▂▁▁▂▃▄▄▄▅▅▅▆▆▆▆▇▆▇▇▇▇▇▇▇▇█▇█████████████
# wandb:       metrics/recall(B) ▄▃▁▃▃▅▆▆▆▆▆▇▆▇▇▇▇▇▇▇▇▇██▇███████████████
# wandb:            model/GFLOPs ▁
# wandb:        model/parameters ▁
# wandb: model/speed_PyTorch(ms) ▁
# wandb:          train/box_loss ▇▇██▇▆▆▆▆▆▆▅▅▅▅▅▅▅▅▅▄▄▄▄▄▄▄▄▄▄▃▃▃▃▂▂▂▁▁▁
# wandb:          train/cls_loss █▄▅▅▄▄▄▄▄▃▃▃▃▃▃▃▃▃▃▃▃▂▂▂▂▂▂▂▂▂▂▂▂▂▂▁▁▁▁▁
# wandb:          train/dfl_loss ███▇▇▆▆▆▆▅▅▅▅▅▄▄▄▄▄▄▄▃▃▃▃▃▃▃▃▃▂▂▂▂▂▂▂▁▁▁
# wandb:            val/box_loss ▅▆█▇▆▅▄▄▄▄▄▃▃▃▃▃▃▃▃▃▂▂▂▂▂▂▂▂▂▂▁▁▁▁▁▁▁▁▁▁
# wandb:            val/cls_loss ▅▆█▅▅▄▃▃▃▃▂▂▂▂▂▂▂▂▂▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁
# wandb:            val/dfl_loss ▆█▇▅▄▄▄▃▃▃▃▂▂▂▂▂▂▂▂▂▂▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁
# wandb:
# wandb: Run summary:
# wandb:                  lr/pg0 0.00027
# wandb:                  lr/pg1 0.00027
# wandb:                  lr/pg2 0.00027
# wandb:        metrics/mAP50(B) 0.93427
# wandb:     metrics/mAP50-95(B) 0.71559
# wandb:    metrics/precision(B) 0.90111
# wandb:       metrics/recall(B) 0.88294
# wandb:            model/GFLOPs 24.822
# wandb:        model/parameters 8076414
# wandb: model/speed_PyTorch(ms) 5.336
# wandb:          train/box_loss 1.29474
# wandb:          train/cls_loss 0.5627
# wandb:          train/dfl_loss 2.29282
# wandb:            val/box_loss 1.85093
# wandb:            val/cls_loss 0.99267
# wandb:            val/dfl_loss 2.81522
# wandb:
# wandb: 🚀 View run yolov10_training at: https://wandb.ai/mehdi-esi-alger/wandb/runs/3ju2iy5n
# wandb: ⭐️ View project at: https://wandb.ai/mehdi-esi-alger/wandb
# wandb: Synced 5 W&B file(s), 0 media file(s), 10 artifact file(s) and 24 other file(s)
# wandb: Find logs at: ./wandb/run-20250212_171805-3ju2iy5n/logs
# 💡 Learn more at https://docs.ultralytics.com/modes/train
