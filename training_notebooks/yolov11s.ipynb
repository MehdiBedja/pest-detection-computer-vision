# %%
# !git clone https://github.com/ultralytics/ultralytics.git
# Out:
# Cloning into 'ultralytics'...
# remote: Enumerating objects: 50676, done.
# remote: Counting objects: 100% (315/315), done.
# remote: Compressing objects: 100% (138/138), done.
# remote: Total 50676 (delta 278), reused 177 (delta 177), pack-reused 50361 (from 3)
# Receiving objects: 100% (50676/50676), 28.90 MiB | 28.98 MiB/s, done.
# Resolving deltas: 100% (37490/37490), done.

# %%
pip install ultralytics --upgrade
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 914.7/914.7 kB 16.7 MB/s eta 0:00:00
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
cd ultralytics
# Out:
# /kaggle/working/ultralytics

# %%
# !pip install -e .
# Out:
# Obtaining file:///kaggle/working/ultralytics
#   Installing build dependencies ... done
#   Checking if build backend supports build_editable ... done
#   Getting requirements to build editable ... done
#   Preparing editable metadata (pyproject.toml) ... done
# ...
#   Building editable for ultralytics (pyproject.toml) ... done
#   Created wheel for ultralytics: filename=ultralytics-8.3.74-0.editable-py3-none-any.whl size=22689 sha256=300e44202584f37295a7932f82956123547c250616c0947be8aba02a6f5ea07f
#   Stored in directory: /tmp/pip-ephem-wheel-cache-kxn34xb7/wheels/1b/eb/7d/853f2df0532389050170c8cd117b40e1fef8d125854a910fe6
# Successfully built ultralytics
# ...
#   Attempting uninstall: ultralytics
#     Found existing installation: ultralytics 8.3.74
#     Uninstalling ultralytics-8.3.74:
#       Successfully uninstalled ultralytics-8.3.74
# ...

# %%
# !ls /kaggle/working/ultralytics
# Out:
# CITATION.cff	 examples	 README.md	  ultralytics.egg-info
# CONTRIBUTING.md  LICENSE	 README.zh-CN.md
# docker		 mkdocs.yml	 tests
# docs		 pyproject.toml  ultralytics

# %%
# !cp -r /kaggle/input/dataset_Yolo_version_13pestTypes /kaggle/working/dataset

# %%
# !echo -e "" > /kaggle/working/dataset.yaml

# %%
yaml_content = """
path: /kaggle/working/dataset
train: train/images
val: val/images
test: test/images

nc: 13
names: ["IP014", "IP015", "IP016", "IP022", "IP024", "IP040", "IP046", "IP049", "IP051", "IP052", "IP071", "IP087", "IP102"]
"""

with open("/kaggle/working/dataset.yaml", "w") as f:
    f.write(yaml_content)

# %%
# !wandb login 4f59467c9d10d7a53805775f226ee2d29eba5e5b
# Out:
# wandb: WARNING If you're specifying your api key in code, ensure this code is not shared publicly.
# wandb: WARNING Consider setting the WANDB_API_KEY environment variable, or running `wandb login` from the command line.
# wandb: Appending key for api.wandb.ai to your netrc file: /root/.netrc

# %%
# !yolo settings wandb=True
# Out:
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.
# JSONDict("/root/.config/Ultralytics/settings.json"):
# {
#   "settings_version": "0.0.6",
#   "datasets_dir": "/kaggle/working/datasets",
#   "weights_dir": "/kaggle/working/ultralytics/weights",
#   "runs_dir": "/kaggle/working/ultralytics/runs",
#   "uuid": "1bfc3e992d24318da58ddee183be5bf9388a31f26bab1738e986ec4d297417ff",
#   "sync": true,
#   "api_key": "",
#   "openai_api_key": "",
#   "clearml": true,
#   "comet": true,
#   "dvc": true,
#   "hub": true,
#   "mlflow": true,
#   "neptune": true,
#   "raytune": true,
#   "tensorboard": true,
#   "wandb": true,
#   "vscode_msg": true
# }
# ...

# %%
# !sed -i 's/ray.train._internal.session._get_session()/ray.train._internal.session.get_session()/g' /kaggle/working/ultralytics/ultralytics/utils/callbacks/raytune.py

# %%
# !yolo task=detect mode=train model=yolo11s.pt \
  data=/kaggle/working/dataset.yaml \
  epochs=60 imgsz=640 batch=16 \
  optimizer=SGD  \
  project="wandb" name="yolov11s1_training"
# Out:
# ...
# 100%|███████████████████████████████████████| 18.4M/18.4M [00:00<00:00, 179MB/s]
# Ultralytics 8.3.74 🚀 Python-3.10.12 torch-2.5.1+cu121 CUDA:0 (Tesla T4, 15095MiB)
# ...
