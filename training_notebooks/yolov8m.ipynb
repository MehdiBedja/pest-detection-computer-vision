# %%
# !git clone https://github.com/ultralytics/ultralytics.git
# Out:
# Cloning into 'ultralytics'...
# remote: Enumerating objects: 50546, done.
# remote: Counting objects: 100% (260/260), done.
# remote: Compressing objects: 100% (138/138), done.
# remote: Total 50546 (delta 194), reused 137 (delta 119), pack-reused 50286 (from 2)
# Receiving objects: 100% (50546/50546), 28.89 MiB | 19.30 MiB/s, done.
# Resolving deltas: 100% (37369/37369), done.

# %%
cd ultralytics
# Out:
# /kaggle/working/ultralytics

# %%
# !pip install -e .
# Out:
# Obtaining file:///kaggle/working/ultralytics
#   Installing build dependencies ... done
#   Checking if build backend supports build_editable ... done
#   Getting requirements to build editable ... done
#   Preparing editable metadata (pyproject.toml) ... done
# Requirement already satisfied: numpy<=2.1.1,>=1.23.0 in /usr/local/lib/python3.10/dist-packages (from ultralytics==8.3.73) (1.26.4)
# Requirement already satisfied: matplotlib>=3.3.0 in /usr/local/lib/python3.10/dist-packages (from ultralytics==8.3.73) (3.7.5)
# Requirement already satisfied: opencv-python>=4.6.0 in /usr/local/lib/python3.10/dist-packages (from ultralytics==8.3.73) (4.10.0.84)
# Requirement already satisfied: pillow>=7.1.2 in /usr/local/lib/python3.10/dist-packages (from ultralytics==8.3.73) (11.0.0)
# Requirement already satisfied: pyyaml>=5.3.1 in /usr/local/lib/python3.10/dist-packages (from ultralytics==8.3.73) (6.0.2)
# Requirement already satisfied: requests>=2.23.0 in /usr/local/lib/python3.10/dist-packages (from ultralytics==8.3.73) (2.32.3)
# Requirement already satisfied: scipy>=1.4.1 in /usr/local/lib/python3.10/dist-packages (from ultralytics==8.3.73) (1.13.1)
# Requirement already satisfied: torch>=1.8.0 in /usr/local/lib/python3.10/dist-packages (from ultralytics==8.3.73) (2.5.1+cu121)
# Requirement already satisfied: torchvision>=0.9.0 in /usr/local/lib/python3.10/dist-packages (from ultralytics==8.3.73) (0.20.1+cu121)
# Requirement already satisfied: tqdm>=4.64.0 in /usr/local/lib/python3.10/dist-packages (from ultralytics==8.3.73) (4.67.1)
# Requirement already satisfied: psutil in /usr/local/lib/python3.10/dist-packages (from ultralytics==8.3.73) (5.9.5)
# Requirement already satisfied: py-cpuinfo in /usr/local/lib/python3.10/dist-packages (from ultralytics==8.3.73) (9.0.0)
# Requirement already satisfied: pandas>=1.1.4 in /usr/local/lib/python3.10/dist-packages (from ultralytics==8.3.73) (2.2.3)
# Requirement already satisfied: seaborn>=0.11.0 in /usr/local/lib/python3.10/dist-packages (from ultralytics==8.3.73) (0.12.2)
# Collecting ultralytics-thop>=2.0.0 (from ultralytics==8.3.73)
#   Downloading ultralytics_thop-2.0.14-py3-none-any.whl.metadata (9.4 kB)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.3.0->ultralytics==8.3.73) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.3.0->ultralytics==8.3.73) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.3.0->ultralytics==8.3.73) (4.55.3)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.3.0->ultralytics==8.3.73) (1.4.7)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.3.0->ultralytics==8.3.73) (24.2)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.3.0->ultralytics==8.3.73) (3.2.0)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.3.0->ultralytics==8.3.73) (2.9.0.post0)
# Requirement already satisfied: mkl_fft in /usr/local/lib/python3.10/dist-packages (from numpy<=2.1.1,>=1.23.0->ultralytics==8.3.73) (1.3.8)
# Requirement already satisfied: mkl_random in /usr/local/lib/python3.10/dist-packages (from numpy<=2.1.1,>=1.23.0->ultralytics==8.3.73) (1.2.4)
# Requirement already satisfied: mkl_umath in /usr/local/lib/python3.10/dist-packages (from numpy<=2.1.1,>=1.23.0->ultralytics==8.3.73) (0.1.1)
# Requirement already satisfied: mkl in /usr/local/lib/python3.10/dist-packages (from numpy<=2.1.1,>=1.23.0->ultralytics==8.3.73) (2025.0.1)
# Requirement already satisfied: tbb4py in /usr/local/lib/python3.10/dist-packages (from numpy<=2.1.1,>=1.23.0->ultralytics==8.3.73) (2022.0.0)
# Requirement already satisfied: mkl-service in /usr/local/lib/python3.10/dist-packages (from numpy<=2.1.1,>=1.23.0->ultralytics==8.3.73) (2.4.1)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.1.4->ultralytics==8.3.73) (2025.1)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.1.4->ultralytics==8.3.73) (2025.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests>=2.23.0->ultralytics==8.3.73) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests>=2.23.0->ultralytics==8.3.73) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests>=2.23.0->ultralytics==8.3.73) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests>=2.23.0->ultralytics==8.3.73) (2025.1.31)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch>=1.8.0->ultralytics==8.3.73) (3.17.0)
# Requirement already satisfied: typing-extensions>=4.8.0 in /usr/local/lib/python3.10/dist-packages (from torch>=1.8.0->ultralytics==8.3.73) (4.12.2)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch>=1.8.0->ultralytics==8.3.73) (3.4.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch>=1.8.0->ultralytics==8.3.73) (3.1.4)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from torch>=1.8.0->ultralytics==8.3.73) (2024.9.0)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.10/dist-packages (from torch>=1.8.0->ultralytics==8.3.73) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from sympy==1.13.1->torch>=1.8.0->ultralytics==8.3.73) (1.3.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.7->matplotlib>=3.3.0->ultralytics==8.3.73) (1.17.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch>=1.8.0->ultralytics==8.3.73) (3.0.2)
# Requirement already satisfied: intel-openmp>=2024 in /usr/local/lib/python3.10/dist-packages (from mkl->numpy<=2.1.1,>=1.23.0->ultralytics==8.3.73) (2024.2.0)
# Requirement already satisfied: tbb==2022.* in /usr/local/lib/python3.10/dist-packages (from mkl->numpy<=2.1.1,>=1.23.0->ultralytics==8.3.73) (2022.0.0)
# Requirement already satisfied: tcmlib==1.* in /usr/local/lib/python3.10/dist-packages (from tbb==2022.*->mkl->numpy<=2.1.1,>=1.23.0->ultralytics==8.3.73) (1.2.0)
# Requirement already satisfied: intel-cmplr-lib-rt in /usr/local/lib/python3.10/dist-packages (from mkl_umath->numpy<=2.1.1,>=1.23.0->ultralytics==8.3.73) (2024.2.0)
# Requirement already satisfied: intel-cmplr-lib-ur==2024.2.0 in /usr/local/lib/python3.10/dist-packages (from intel-openmp>=2024->mkl->numpy<=2.1.1,>=1.23.0->ultralytics==8.3.73) (2024.2.0)
# Downloading ultralytics_thop-2.0.14-py3-none-any.whl (26 kB)
# Building wheels for collected packages: ultralytics
#   Building editable for ultralytics (pyproject.toml) ... done
#   Created wheel for ultralytics: filename=ultralytics-8.3.73-0.editable-py3-none-any.whl size=22691 sha256=56b64ecbf7135d8ebfcd7c296c9963db44088a9fa430ea04e2dfc15fe0c4d9d0
#   Stored in directory: /tmp/pip-ephem-wheel-cache-7ir3d7dd/wheels/1b/eb/7d/853f2df0532389050170c8cd117b40e1fef8d125854a910fe6
# Successfully built ultralytics
# Installing collected packages: ultralytics-thop, ultralytics
# Successfully installed ultralytics-8.3.73 ultralytics-thop-2.0.14

# %%
# !ls /kaggle/working/ultralytics
# Out:
# CITATION.cff	 examples	 README.md	  ultralytics.egg-info
# CONTRIBUTING.md  LICENSE	 README.zh-CN.md
# docker		 mkdocs.yml	 tests
# docs		 pyproject.toml  ultralytics

# %%
# !cp -r /kaggle/input/dataset-yolo-v1-0-13pesttypes/dataset_Yolo_version_13pestTypes /kaggle/working/dataset

# %%
# !echo -e "" > /kaggle/working/dataset.yaml

# %%
yaml_content = """
path: /kaggle/working/dataset
train: train/images
val: val/images
test: test/images

nc: 13
names: ["IP014", "IP015", "IP016", "IP022", "IP024", "IP040", "IP046", "IP049", "IP051", "IP052", "IP071", "IP087", "IP102"]
"""

with open("/kaggle/working/dataset.yaml", "w") as f:
    f.write(yaml_content)

# %%
# !wandb login 4f59467c9d10d7a53805775f226ee2d29eba5e5b
# Out:
# wandb: WARNING If you're specifying your api key in code, ensure this code is not shared publicly.
# wandb: WARNING Consider setting the WANDB_API_KEY environment variable, or running `wandb login` from the command line.
# wandb: Appending key for api.wandb.ai to your netrc file: /root/.netrc

# %%
# !yolo settings wandb=True
# Out:
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.
# JSONDict("/root/.config/Ultralytics/settings.json"):
# {
#   "settings_version": "0.0.6",
#   "datasets_dir": "/kaggle/working/datasets",
#   "weights_dir": "/kaggle/working/ultralytics/weights",
#   "runs_dir": "/kaggle/working/ultralytics/runs",
#   "uuid": "1bfc3e992d24318da58ddee183be5bf9388a31f26bab1738e986ec4d297417ff",
#   "sync": true,
#   "api_key": "",
#   "openai_api_key": "",
#   "clearml": true,
#   "comet": true,
#   "dvc": true,
#   "hub": true,
#   "mlflow": true,
#   "neptune": true,
#   "raytune": true,
#   "tensorboard": true,
#   "wandb": true,
#   "vscode_msg": true
# }
# 💡 Learn more about Ultralytics Settings at https://docs.ultralytics.com/quickstart/#ultralytics-settings

# %%
# !sed -i 's/ray.train._internal.session._get_session()/ray.train._internal.session.get_session()/g' /kaggle/working/ultralytics/ultralytics/utils/callbacks/raytune.py

# %%
# !yolo task=detect mode=train model=yolov8m.pt \
  data=/kaggle/working/dataset.yaml \
  epochs=60 imgsz=640 batch=16 \
  optimizer=SGD  \
  project="wandb" name="yolov8_training"
# Out:
# Downloading https://github.com/ultralytics/assets/releases/download/v8.3.0/yolov8m.pt to 'yolov8m.pt'...
# 100%|███████████████████████████████████████| 49.7M/49.7M [00:00<00:00, 196MB/s]
# Ultralytics 8.3.73 🚀 Python-3.10.12 torch-2.5.1+cu121 CUDA:0 (Tesla T4, 15095MiB)
# engine/trainer: task=detect, mode=train, model=yolov8m.pt, data=/kaggle/working/dataset.yaml, epochs=60, time=None, patience=100, batch=16, imgsz=640, save=True, save_period=-1, cache=False, device=None, workers=8, project=wandb, name=yolov8_training, exist_ok=False, pretrained=True, optimizer=SGD, verbose=True, seed=0, deterministic=True, single_cls=False, rect=False, cos_lr=False, close_mosaic=10, resume=False, amp=True, fraction=1.0, profile=False, freeze=None, multi_scale=False, overlap_mask=True, mask_ratio=4, dropout=0.0, val=True, split=val, save_json=False, save_hybrid=False, conf=None, iou=0.7, max_det=300, half=False, dnn=False, plots=True, source=None, vid_stride=1, stream_buffer=False, visualize=False, augment=False, agnostic_nms=False, classes=None, retina_masks=False, embed=None, show=False, save_frames=False, save_txt=False, save_conf=False, save_crop=False, show_labels=True, show_conf=True, show_boxes=True, line_width=None, format=torchscript, keras=False, optimize=False, int8=False, dynamic=False, simplify=True, opset=None, workspace=None, nms=False, lr0=0.01, lrf=0.01, momentum=0.937, weight_decay=0.0005, warmup_epochs=3.0, warmup_momentum=0.8, warmup_bias_lr=0.1, box=7.5, cls=0.5, dfl=1.5, pose=12.0, kobj=1.0, nbs=64, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, degrees=0.0, translate=0.1, scale=0.5, shear=0.0, perspective=0.0, flipud=0.0, fliplr=0.5, bgr=0.0, mosaic=1.0, mixup=0.0, copy_paste=0.0, copy_paste_mode=flip, auto_augment=randaugment, erasing=0.4, crop_fraction=1.0, cfg=None, tracker=botsort.yaml, save_dir=wandb/yolov8_training
# Downloading https://ultralytics.com/assets/Arial.ttf to '/root/.config/Ultralytics/Arial.ttf'...
# 100%|████████████████████████████████████████| 755k/755k [00:00<00:00, 16.5MB/s]
# Overriding model.yaml nc=80 with nc=13
#
#                    from  n    params  module                                       arguments
#   0                  -1  1      1392  ultralytics.nn.modules.conv.Conv             [3, 48, 3, 2]
#   1                  -1  1     41664  ultralytics.nn.modules.conv.Conv             [48, 96, 3, 2]
#   2                  -1  2    111360  ultralytics.nn.modules.block.C2f             [96, 96, 2, True]
#   3                  -1  1    166272  ultralytics.nn.modules.conv.Conv             [96, 192, 3, 2]
#   4                  -1  4    813312  ultralytics.nn.modules.block.C2f             [192, 192, 4, True]
#   5                  -1  1    664320  ultralytics.nn.modules.conv.Conv             [192, 384, 3, 2]
#   6                  -1  4   3248640  ultralytics.nn.modules.block.C2f             [384, 384, 4, True]
#   7                  -1  1   1991808  ultralytics.nn.modules.conv.Conv             [384, 576, 3, 2]
#   8                  -1  2   3985920  ultralytics.nn.modules.block.C2f             [576, 576, 2, True]
#   9                  -1  1    831168  ultralytics.nn.modules.block.SPPF            [576, 576, 5]
#  10                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  11             [-1, 6]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  12                  -1  2   1993728  ultralytics.nn.modules.block.C2f             [960, 384, 2]
#  13                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  14             [-1, 4]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  15                  -1  2    517632  ultralytics.nn.modules.block.C2f             [576, 192, 2]
#  16                  -1  1    332160  ultralytics.nn.modules.conv.Conv             [192, 192, 3, 2]
#  17            [-1, 12]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  18                  -1  2   1846272  ultralytics.nn.modules.block.C2f             [576, 384, 2]
#  19                  -1  1   1327872  ultralytics.nn.modules.conv.Conv             [384, 384, 3, 2]
#  20             [-1, 9]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  21                  -1  2   4207104  ultralytics.nn.modules.block.C2f             [960, 576, 2]
#  22        [15, 18, 21]  1   3783223  ultralytics.nn.modules.head.Detect           [13, [192, 384, 576]]
# Model summary: 295 layers, 25,863,847 parameters, 25,863,831 gradients, 79.1 GFLOPs
#
# Transferred 469/475 items from pretrained weights
# TensorBoard: Start with 'tensorboard --logdir wandb/yolov8_training', view at http://localhost:6006/
# wandb: Using wandb-core as the SDK backend.  Please refer to https://wandb.me/wandb-core for more information.
# wandb: Currently logged in as: younes1967-yy (mehdi-esi-alger). Use `wandb login --relogin` to force relogin
# wandb: Tracking run with wandb version 0.19.1
# wandb: Run data is saved locally in /kaggle/working/ultralytics/wandb/run-20250209_190559-ctxajn8v
# wandb: Run `wandb offline` to turn off syncing.
# wandb: Syncing run yolov8_training
# wandb: ⭐️ View project at https://wandb.ai/mehdi-esi-alger/wandb
# wandb: 🚀 View run at https://wandb.ai/mehdi-esi-alger/wandb/runs/ctxajn8v
# Freezing layer 'model.22.dfl.conv.weight'
# AMP: running Automatic Mixed Precision (AMP) checks...
# Downloading https://github.com/ultralytics/assets/releases/download/v8.3.0/yolo11n.pt to 'yolo11n.pt'...
# 100%|██████████████████████████████████████| 5.35M/5.35M [00:00<00:00, 70.7MB/s]
# AMP: checks passed ✅
# train: Scanning /kaggle/working/dataset/train/labels... 8745 images, 0 backgroun
# train: New cache created: /kaggle/working/dataset/train/labels.cache
# /usr/local/lib/python3.10/dist-packages/albumentations/__init__.py:24: UserWarning: A new version of Albumentations is available: 2.0.3 (you have 1.4.20). Upgrade using: pip install -U albumentations. To disable automatic update checks, set the environment variable NO_ALBUMENTATIONS_UPDATE to 1.
#   check_for_updates()
# albumentations: Blur(p=0.01, blur_limit=(3, 7)), MedianBlur(p=0.01, blur_limit=(3, 7)), ToGray(p=0.01, num_output_channels=3, method='weighted_average'), CLAHE(p=0.01, clip_limit=(1.0, 4.0), tile_grid_size=(8, 8))
# val: Scanning /kaggle/working/dataset/val/labels... 1089 images, 0 backgrounds,
# val: New cache created: /kaggle/working/dataset/val/labels.cache
# Plotting labels to wandb/yolov8_training/labels.jpg...
# optimizer: SGD(lr=0.01, momentum=0.937) with parameter groups 77 weight(decay=0.0), 84 weight(decay=0.0005), 83 bias(decay=0.0)
# TensorBoard: model graph visualization added ✅
# Image sizes 640 train, 640 val
# Using 2 dataloader workers
# Logging results to wandb/yolov8_training
# Starting training for 60 epochs...
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        1/60      6.81G      1.271      2.352      1.581         25        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all       1089       1618      0.569       0.69      0.667      0.431
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        2/60      6.75G      1.167      1.457       1.46         22        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all       1089       1618      0.608      0.657      0.648      0.397
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        3/60      6.77G      1.258      1.553      1.532         37        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all       1089       1618      0.503      0.491      0.485      0.281
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        4/60      6.76G      1.314      1.674      1.577         31        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all       1089       1618      0.602      0.628       0.65      0.391
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        5/60      6.74G      1.282      1.564       1.55         27        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all       1089       1618      0.623      0.633      0.671      0.422
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        6/60      6.73G      1.244      1.503      1.524         36        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all       1089       1618      0.692      0.725      0.755      0.478
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        7/60      6.66G      1.227      1.415      1.512         21        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all       1089       1618      0.708      0.658      0.725      0.472
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        8/60      6.75G      1.188       1.33      1.482         27        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all       1089       1618      0.716      0.755      0.778      0.518
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        9/60      6.73G      1.176      1.295      1.472         26        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all       1089       1618      0.732       0.78      0.811      0.539
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       10/60      6.74G      1.153      1.239      1.458         25        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all       1089       1618      0.768      0.787      0.838      0.562
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       11/60      6.66G      1.143      1.208      1.452         24        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all       1089       1618      0.783      0.788       0.84      0.558
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       12/60      6.75G      1.125      1.165       1.43         36        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all       1089       1618      0.806      0.815       0.87      0.597
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       13/60      6.76G      1.113      1.131      1.427         24        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all       1089       1618      0.803      0.824       0.87       0.59
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       14/60      6.76G      1.101      1.114      1.427         31        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all       1089       1618      0.792      0.831      0.873      0.602
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       15/60      6.64G      1.093      1.069      1.409         31        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all       1089       1618      0.845      0.829      0.892      0.626
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       16/60      6.76G      1.075      1.041        1.4         25        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all       1089       1618      0.819      0.834      0.882      0.617
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       17/60      6.74G      1.073      1.012      1.397         32        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all       1089       1618      0.842      0.839      0.893      0.623
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       18/60      6.74G      1.049     0.9806      1.383         34        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all       1089       1618      0.814      0.846      0.894      0.633
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       19/60      6.66G      1.054     0.9684      1.389         33        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all       1089       1618      0.847      0.858      0.903      0.635
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       20/60
parameters, 0 gradients, 78.7 GFLOPs
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all       1089       1618      0.892      0.905       0.94      0.723
#                  IP014         83        197      0.957       0.97      0.985      0.826
#                  IP015         86         87      0.977      0.967      0.993      0.598
#                  IP016         82        146      0.954      0.984       0.98      0.901
#                  IP022         82        124      0.938      0.984      0.976      0.849
#                  IP024         87        155      0.775      0.748      0.812       0.46
#                  IP040         81        122      0.928      0.949      0.982      0.873
#                  IP046         80        130      0.903      0.934      0.964      0.868
#                  IP049         83        123      0.813      0.917      0.937      0.768
#                  IP051         83        134      0.901      0.887      0.948      0.779
#                  IP052         87         92      0.775      0.761      0.847      0.419
#                  IP071         87         87      0.796      0.759      0.835       0.46
#                  IP087         81        132      0.908      0.947      0.978       0.87
#                  IP102         87         89      0.977       0.96      0.977      0.723
# /usr/local/lib/python3.10/dist-packages/matplotlib/colors.py:721: RuntimeWarning: invalid value encountered in less
#   xa[xa < 0] = -1
# /usr/local/lib/python3.10/dist-packages/matplotlib/colors.py:721: RuntimeWarning: invalid value encountered in less
#   xa[xa < 0] = -1
# Speed: 0.1ms preprocess, 7.9ms inference, 0.0ms loss, 0.8ms postprocess per image
# Results saved to wandb/yolov8_training
# wandb:
# wandb:
# wandb: Run history:
# wandb:                  lr/pg0 █▅▂▂▂▂▂▂▂▂▂▂▂▂▂▂▂▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁
# wandb:                  lr/pg1 ▃▆████▇▇▇▇▇▇▆▆▆▆▅▅▅▅▅▄▄▄▄▄▄▃▃▃▃▃▃▂▂▂▂▂▁▁
# wandb:                  lr/pg2 ▃▆████▇▇▇▇▇▇▇▆▆▆▆▆▆▆▅▅▅▄▄▄▄▄▃▃▃▃▃▃▂▂▂▁▁▁
# wandb:        metrics/mAP50(B) ▃▁▄▄▅▅▆▆▇▇▇▇▇▇██████████████████████████
# wandb:     metrics/mAP50-95(B) ▁▃▄▄▅▅▅▆▆▆▆▇▇▇▇▇▇▇▇▇▇▇██████████████████
# wandb:    metrics/precision(B) ▁▂▂▂▃▄▅▅▆▆▆▇▆▇▇▇▇▇▇▇▇▇▇▇█▇██████████████
# wandb:       metrics/recall(B) ▄▁▃▅▆▆▆▇▇▇▇▇▇▇▇▇▇▇▇██▇▇▇██▇▇████████████
# wandb:            model/GFLOPs ▁
# wandb:        model/parameters ▁
# wandb: model/speed_PyTorch(ms) ▁
# wandb:          train/box_loss █▇███▇▇▇▇▆▆▆▆▆▆▅▅▅▅▅▅▅▅▄▄▄▄▄▄▄▃▃▃▃▃▂▂▁▁▁
# wandb:          train/cls_loss █▅▅▆▅▅▄▄▄▄▄▄▃▃▃▃▃▃▃▃▃▂▂▂▂▂▂▂▂▂▂▂▁▁▁▁▁▁▁▁
# wandb:          train/dfl_loss █▆▇██▇▇▆▆▆▆▆▆▅▅▅▅▅▅▅▅▄▄▄▄▄▃▃▃▃▃▃▃▃▂▂▂▁▁▁
# wandb:            val/box_loss █▆▅▅▄▄▄▄▃▃▃▃▃▃▃▃▂▂▂▂▂▂▂▂▂▂▂▂▁▁▁▁▁▁▁▁▁▁▁▁
# wandb:            val/cls_loss ▇▇█▇▆▅▅▄▄▃▃▃▃▃▃▂▂▂▂▂▂▂▂▂▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁
# wandb:            val/dfl_loss ▃▅█▅▅▄▄▃▃▃▂▃▂▂▂▂▂▂▂▂▂▂▂▂▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁
# wandb:
# wandb: Run summary:
# wandb:                  lr/pg0 0.00027
# wandb:                  lr/pg1 0.00027
# wandb:                  lr/pg2 0.00027
# wandb:        metrics/mAP50(B) 0.93951
# wandb:     metrics/mAP50-95(B) 0.72259
# wandb:    metrics/precision(B) 0.89245
# wandb:       metrics/recall(B) 0.9051
# wandb:            model/GFLOPs 79.104
# wandb:        model/parameters 25863847
# wandb: model/speed_PyTorch(ms) 8.151
# wandb:          train/box_loss 0.53258
# wandb:          train/cls_loss 0.25602
# wandb:          train/dfl_loss 1.07026
# wandb:            val/box_loss 0.86716
# wandb:            val/cls_loss 0.48124
# wandb:            val/dfl_loss 1.41321
# wandb:
# wandb: 🚀 View run yolov8_training at: https://wandb.ai/mehdi-esi-alger/wandb/runs/ctxajn8v
# wandb: ⭐️ View project at: https://wandb.ai/mehdi-esi-alger/wandb
# wandb: Synced 5 W&B file(s), 0 media file(s), 10 artifact file(s) and 24 other file(s)
# wandb: Find logs at: ./wandb/run-20250209_190559-ctxajn8v/logs
# 💡 Learn more at https://docs.ultralytics.com/modes/train
